# %% [markdown]
# # ***RANDOM***

# %%
import random

# Generate 10 random integers between 1 and 100
for i in range(10):
    print(random.randint(1, 100))
# Out:
# 4
# 42
# 30
# 25
# 19
# 37
# 20
# 87
# 28
# 66

# %%
'''
import random

# =========================
# INTEGERS
# =========================
random.randint(1, 100)          # Integer between 1 and 100 (inclusive)
random.randrange(1, 100)        # Integer from 1 to 99
random.randrange(0, 100, 5)     # Random multiple of 5

# =========================
# DECIMALS
# =========================
random.random()                 # Float between 0.0 and 1.0
random.uniform(1, 100)          # Float between 1 and 100

# =========================
# LIST OPERATIONS
# =========================
random.choice(['A', 'B', 'C'])              # One random element
random.choices(['A', 'B', 'C'], k=5)        # 5 elements (duplicates allowed)
random.sample(['A', 'B', 'C', 'D'], k=2)    # 2 unique elements

# =========================
# SHUFFLING
# =========================
lst = [1,2,3,4,5]
random.shuffle(lst)             # Shuffle list in-place

# =========================
# RANDOM BITS
# =========================
random.getrandbits(8)           # Random 8-bit integer (0-255)

# =========================
# PROBABILITY
# =========================
random.random() < 0.5           # 50% chance True/False

# =========================
# BOOLEAN
# =========================
random.choice([True, False])    # Random boolean

# =========================
# RANDOM LETTER
# =========================
import string
random.choice(string.ascii_letters)   # Random letter
random.choice(string.ascii_uppercase) # Random uppercase
random.choice(string.digits)          # Random digit

# =========================
# RANDOM STRING
# =========================
''.join(random.choices(string.ascii_letters, k=10))
''.join(random.choices(string.digits, k=8))
''.join(random.choices(string.ascii_letters + string.digits, k=12))

# =========================
# RANDOM DATE (simple)
# =========================
from datetime import date, timedelta

start = date(2020, 1, 1)
random_date = start + timedelta(days=random.randint(0, 365))
print(random_date)

# =========================
# SET SEED
# =========================
random.seed(42)                 # Same random values every run

'''

# %%
'''
#Most Commanly Used

random.randint()
random.randrange()
random.random()
random.uniform()
random.choice()
random.choices()
random.sample()
random.shuffle()
random.getrandbits()
random.seed()
'''

# %% [markdown]
# # ***FAKER***

# %%
# !pip install faker

from faker import Faker
fake = Faker()
for i in range(10):
    print(fake.name())
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.7 MB/s eta 0:00:00
# ...
# Robert Barker
# Karen Moore
# Amanda Pierce
# Cassandra Jones
# Alejandra Campbell
# Christopher Russell
# Richard Davis
# Valerie Novak
# Melanie Martin
# Christopher Fisher

# %%
'''
# =========================
# PERSON
# =========================
fake.name()                    # Full name
fake.first_name()              # First name
fake.last_name()               # Last name
fake.prefix()                  # Mr., Mrs., Dr.
fake.suffix()                  # Jr., Sr.
fake.gender()                  # Gender (if supported)
fake.profile()                 # Complete fake profile

# =========================
# CONTACT
# =========================
fake.email()                   # Email
fake.ascii_email()             # ASCII email
fake.free_email()              # Gmail/Yahoo-like email
fake.company_email()           # Company email
fake.phone_number()            # Phone number

# =========================
# ADDRESS
# =========================
fake.address()                 # Full address
fake.street_address()          # Street
fake.city()                    # City
fake.state()                   # State
fake.country()                 # Country
fake.postcode()                # ZIP/PIN code
fake.latitude()                # Latitude
fake.longitude()               # Longitude

# =========================
# COMPANY
# =========================
fake.company()                 # Company name
fake.company_suffix()          # Pvt Ltd, Inc
fake.job()                     # Job title
fake.bs()                      # Business slogan

# =========================
# DATE & TIME
# =========================
fake.date()                    # Random date
fake.time()                    # Time
fake.date_time()               # Date & Time
fake.date_of_birth()           # DOB
fake.year()                    # Year
fake.month()                   # Month
fake.day_of_month()            # Day

# =========================
# INTERNET
# =========================
fake.user_name()               # Username
fake.password()                # Password
fake.url()                     # Website
fake.domain_name()             # Domain
fake.ipv4()                    # IPv4
fake.ipv6()                    # IPv6
fake.mac_address()             # MAC address
fake.uri()                     # URI

# =========================
# IDENTIFIERS
# =========================
fake.uuid4()                   # UUID
fake.ssn()                     # Fake SSN
fake.license_plate()           # Vehicle number
fake.ean13()                   # Barcode
fake.isbn13()                  # ISBN

# =========================
# FINANCE
# =========================
fake.credit_card_number()      # Credit card number
fake.credit_card_provider()    # Visa/Mastercard
fake.credit_card_expire()      # Expiry date
fake.currency_code()           # USD, INR
fake.currency_name()           # Dollar, Rupee
fake.iban()                    # IBAN

# =========================
# TEXT
# =========================
fake.word()                    # Single word
fake.words()                   # List of words
fake.sentence()                # Sentence
fake.sentences()               # Multiple sentences
fake.paragraph()               # Paragraph
fake.text()                    # Random text

# =========================
# COLORS
# =========================
fake.color_name()              # Blue
fake.hex_color()               # #A1B2C3
fake.rgb_color()               # RGB value

# =========================
# NUMBERS
# =========================
fake.random_int()              # Random integer
fake.random_digit()            # 0-9
fake.random_number()           # Random number
fake.pyfloat()                 # Random float
fake.pydecimal()               # Random decimal
fake.pybool()                  # True/False

# =========================
# MISC
# =========================
fake.boolean()                 # Boolean
fake.language_name()           # English
fake.country_code()            # IN, US
fake.file_name()               # File name
fake.mime_type()               # MIME type
fake.image_url()               # Image URL
fake.emoji()                   # Random emoji (newer versions)


# =========================
# REGION
# =========================
Faker()          # Default (mostly US-style)
Faker("en_IN")   # India
Faker("en_US")   # USA
Faker("en_GB")   # United Kingdom
Faker("fr_FR")   # France
Faker("de_DE")   # Germany
Faker("ja_JP")   # Japan
Faker("ko_KR")   # South Korea
Faker("zh_CN")   # China
'''

# %%
'''
#Most Commanly Used

fake.name()
fake.age()                     # (Not available directly; use random_int)
fake.random_int(18, 60)
fake.email()
fake.phone_number()
fake.address()
fake.city()
fake.state()
fake.country()
fake.company()
fake.job()
fake.date_of_birth()
fake.date()
fake.user_name()
fake.password()
fake.uuid4()
fake.credit_card_number()
fake.word()
fake.sentence()
fake.paragraph()
fake.random_int()
fake.pyfloat()
'''

# %% [markdown]
# # ***EXAMPLE***

# %%
import random
import pandas as pd
from faker import Faker

# Create Faker object
fake = Faker("en_IN")

# Store all rows
data = []

# Generate 10 customers
for i in range(10):
    customer = {
        "Customer_ID": random.randint(1000, 9999),
        "Name": fake.name(),
        "Age": random.randint(18, 70),
        "Gender": random.choice(["Male", "Female"]),
        "Email": fake.email(),
        "City": fake.city(),
        "Salary": random.randint(30000, 120000)
    }

    data.append(customer)

# Convert list of dictionaries into a DataFrame
df = pd.DataFrame(data)

# Display table
print(df)
# Out:
#    Customer_ID             Name  Age  Gender                          Email  \
# 0         6844       Darsh Nagi   43    Male             bmanda@example.com
# 1         3825    Hemani Chopra   67    Male        inayaramesh@example.com
# 2         4187      Pushti More   44    Male       rakshabakshi@example.com
# 3         4798       Fitan Mall   26  Female        oommendivya@example.org
# 4         1438    Rachit Pingle   56    Male  brindaviswanathan@example.net
# 5         4283   Nachiket Tella   57  Female          madhavi93@example.net
# 6         8056    Dakshesh Bala   34  Female     mallickyoshita@example.net
# 7         2354     Dhriti Soman   66  Female         chatresh03@example.com
# 8         8805  Samarth Agrawal   39    Male      yoshitachadha@example.com
# 9         5822     Ojasvi Golla   48  Female      chandrabhavya@example.com
#
#                    City  Salary
# 0               Asansol   67986
# 1          Secunderabad  110440
# 2                Bokaro   88998
# ...
